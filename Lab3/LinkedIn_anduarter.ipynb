# %% [markdown]
# <a href="https://colab.research.google.com/github/anduarter/MetNumUN2022II/blob/main/Lab3/LinkedIn_anduarter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Perfil de LinkedIn: https://www.linkedin.com/in/andr%C3%A9s-felipe-duarte-rojas-720599249/

# %% [markdown]
# ![capturaaa.PNG](data:image/png;base64,...)
